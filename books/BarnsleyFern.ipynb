# %%
from tqdm import trange
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x, y = 0.0, 0
n_iters = 50000
X, Y = [x], [y]

def navigate_to_next_point(x, y):
    rand = random.uniform(0, 100)
    if rand < 1:
        return 0, 0.16*y
    elif 1 <= rand < 86:
        return 0.85*x + 0.04*y, -0.04*x + 0.85*y + 1.6
    elif 86 <= rand < 93:
        return 0.2*x - 0.26*y, 0.23*x + 0.22*y + 1.6
    else:
        return -0.15*x + 0.28*y, 0.26*x + 0.24*y + 0.44

for i in trange(n_iters):
        x, y = navigate_to_next_point(x, y)
        X.append(x); Y.append(y)

plt.figure(figsize=(10, 15))
plt.scatter(X, Y, marker='.', color='green')
plt.axis('off')
plt.title("Barnsley's fern")
# Out:
# 100%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ| 50000/50000 [00:00<00:00, 331106.96it/s]
