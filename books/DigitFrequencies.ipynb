# %%
from tqdm import tqdm
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
digits = ''.join([str(i) for i in range(1*100*1000)])

# %%
plt.subplots(figsize=(10, 10))
lastax = None
for index, no in enumerate('0123456789'):
    index += 1
    zes = np.array([i == no for i in digits])

    seq = 100
    zes = zes[:seq*(zes.shape[0]//seq)].reshape((zes.shape[0]//seq, seq))
    values = []
    for i in zes:
        values.append(i.sum())
    lastax = plt.subplot(10, 1, index)
    plt.plot(values, label=no)
    plt.legend()

# %%
x = np.array([int(i) for i in digits])

# %%
from collections import Counter
point = 3000

Counter(x[point-100:point+100]).most_common()
# Out:
# [(1, 65),
#  (0, 63),
#  (2, 15),
#  (3, 15),
#  (4, 15),
#  (5, 7),
#  (6, 5),
#  (7, 5),
#  (8, 5),
#  (9, 5)]
